# %% [markdown]
# ## Implementing Autoencoders and Variational Autoencoder using Keras
#
# In this lab lesson, we will look into the implementation of Autoencoders (AE) and Variational Autoencoder (VAE) using Keras. The tutorial is based on the code provided by https://blog.keras.io/building-autoencoders-in-keras.html, and https://keras.io/examples/generative/vae.

# %% [markdown]
# ## Load MNIST Dataset
# Load MNIST dataset from keras.datasets

# %%
import keras
from keras import layers
from keras import ops
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import tensorflow as tf
from matplotlib.cm import get_cmap

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
print("=============================================================")
print("Before Conversion:")
print(x_train.shape)
print(x_test.shape)
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print("=============================================================")
print("After Conversion:")
print(x_train.shape)
print(x_test.shape)
print("=============================================================")
# Out:
# =============================================================
# Before Conversion:
# (60000, 28, 28)
# (10000, 28, 28)
# =============================================================
# After Conversion:
# (60000, 784)
# (10000, 784)
# =============================================================

# %% [markdown]
# ## Helper Functions
# Defining helper functions to plot the results

# %%
#Function to plot loss and accuracy curves
def plot_curve(log, valid=True):
    N_train = len(log.history['loss'])
    if valid:
      N_valid = len(log.history['val_loss'])

    plt.figure(figsize=(18,4))

    # Plot loss on training and validation set
    plt.plot(log.history['loss'])

    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.grid('on')
    if valid:
      plt.plot(np.linspace(0,N_train-1,N_valid), log.history['val_loss'])
      plt.legend(['Train', 'Validation'])
    plt.show()

def pred(imgs):
    n = 10  # How many digits we will display
    plt.figure(figsize=(20, 2))
    for i in range(n):

        # Display reconstruction
        ax = plt.subplot(1, n, i + 1)
        plt.imshow(imgs[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

def denoise_pred(imgs):
    n = 10  # How many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(x_test_noisy[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(imgs[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

def cifar(x,y):
    n = 10
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(x[i])
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(y[i])
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

def plot_label_clusters(model, data, labels, vae=False):
    # display a 2D plot of the digit classes in the latent space
    if vae:
      z_mean, _, _ = model.encoder.predict(data, verbose=0)
    else:
      z_mean = model.predict(data, verbose=0)

    cmap = get_cmap("tab10")  # Colormap for up to 10 discrete classes

    plt.figure(figsize=(12, 10))
    for digit in range(10):
        mask = labels == digit
        plt.scatter(
            z_mean[mask, 0], z_mean[mask, 1],
            label=f"{digit}",  # Show digit in the legend
            color=cmap(digit),
            alpha=0.7
        )

    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.legend(loc="best", title="Digits", fontsize='medium')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## 1. Autoencoder

# %% [markdown]
# ### 1.1 Model Definition

# %%
#define encoder network
encoder = keras.Sequential(name='Encoder')
encoder.add(layers.Dense(128, activation='relu',input_shape=(784,),name='Encoder_Layer1'))
encoder.add(layers.Dense(64, activation='relu',name='Encoder_Layer2'))
encoder.add(layers.Dense(2, activation='relu',name='Encoder_Layer3'))
encoder.summary()

#define decoder network
decoder = keras.Sequential(name='Decoder')
decoder.add(layers.Dense(64, activation='relu', input_shape=(2,),name='Decoder_Layer1'))
decoder.add(layers.Dense(128, activation='relu',name='Decoder_Layer2'))
decoder.add(layers.Dense(784, activation='sigmoid',name='Output'))
decoder.summary()

#define autoencoder by combining encoder and decoder
input_img = keras.Input(shape=(784,),name='Input_Layer')
z = encoder(input_img)
output_img = decoder(z)
autoencoder = keras.models.Model(inputs=input_img, outputs=output_img, name='Autoencoder')
autoencoder.summary()
# Out:
# c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "Encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Encoder_Layer1 (Dense)          │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Layer2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Layer3 (Dense)          │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,866 (425.26 KB)
#  Trainable params: 108,866 (425.26 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "Decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Decoder_Layer1 (Dense)          │ (None, 64)             │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Layer2 (Dense)          │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 784)            │       101,136 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,648 (428.31 KB)
#  Trainable params: 109,648 (428.31 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "Autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder (Sequential)            │ (None, 2)              │       108,866 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder (Sequential)            │ (None, 784)            │       109,648 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 218,514 (853.57 KB)
#  Trainable params: 218,514 (853.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 1.2 Model Training

# %%
#Configure the model for training
autoencoder.compile(optimizer='adam', loss='mse')

#Model Training
log = autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_split=0.2)

#Plot loss curves
plot_curve(log)
# Out:
# Epoch 1/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1150 - val_loss: 0.0603
# Epoch 2/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0588 - val_loss: 0.0541
# Epoch 3/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0536 - val_loss: 0.0513
# Epoch 4/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0512 - val_loss: 0.0496
# Epoch 5/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0493 - val_loss: 0.0478
# Epoch 6/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0480 - val_loss: 0.0466
# Epoch 7/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0467 - val_loss: 0.0457
# Epoch 8/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0458 - val_loss: 0.0450
# Epoch 9/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0452 - val_loss: 0.0445
# Epoch 10/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0446 - val_loss: 0.0440
# Epoch 11/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0441 - val_loss: 0.0436
# Epoch 12/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0436 - val_loss: 0.0433
# Epoch 13/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0432 - val_loss: 0.0430
# Epoch 14/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0429 - val_loss: 0.0427
# Epoch 15/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0425 - val_loss: 0.0424
# Epoch 16/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0421 - val_loss: 0.0421
# Epoch 17/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0419 - val_loss: 0.0418
# Epoch 18/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0417 - val_loss: 0.0415
# Epoch 19/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0414 - val_loss: 0.0413
# Epoch 20/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0411 - val_loss: 0.0412
# Epoch 21/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0408 - val_loss: 0.0411
# Epoch 22/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0406 - val_loss: 0.0410
# Epoch 23/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0406 - val_loss: 0.0408
# Epoch 24/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0403 - val_loss: 0.0406
# Epoch 25/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0401 - val_loss: 0.0406
# Epoch 26/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0400 - val_loss: 0.0405
# Epoch 27/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0398 - val_loss: 0.0403
# Epoch 28/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0397 - val_loss: 0.0402
# Epoch 29/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0396 - val_loss: 0.0401
# Epoch 30/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0394 - val_loss: 0.0400
# Epoch 31/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0391 - val_loss: 0.0402
# Epoch 32/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0391 - val_loss: 0.0401
# Epoch 33/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0391 - val_loss: 0.0400
# Epoch 34/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0388 - val_loss: 0.0399
# Epoch 35/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0389 - val_loss: 0.0398
# Epoch 36/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0388 - val_loss: 0.0398
# Epoch 37/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0387 - val_loss: 0.0398
# Epoch 38/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0387 - val_loss: 0.0397
# Epoch 39/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0387 - val_loss: 0.0397
# Epoch 40/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0385 - val_loss: 0.0396
# Epoch 41/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0386 - val_loss: 0.0396
# Epoch 42/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0384 - val_loss: 0.0395
# Epoch 43/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0385 - val_loss: 0.0394
# Epoch 44/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0383 - val_loss: 0.0395
# Epoch 45/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 46/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 47/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0381 - val_loss: 0.0394
# Epoch 48/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0379 - val_loss: 0.0393
# Epoch 49/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0380 - val_loss: 0.0393
# Epoch 50/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0379 - val_loss: 0.0392

# %% [markdown]
# ### 1.3 Display Results

# %%
test = autoencoder.predict(x_test)
pred(x_test)
pred(test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### 1.4 Reconstruction with AE

# %%
#Get the encoded values for test images
latent_z = encoder(x_test)

#Get the decoded images from the encoded values
decoded_img = decoder(latent_z)

#Plot test and decoded images
pred(x_test)
pred(decoded_img.numpy())

# %% [markdown]
# ### 1.5 Interpolation with AE

# %%
#Get the encoded values for test images
latent_z1 = encoder(x_test[:10, :])
latent_z2 = encoder(x_test[10:20, :])

#Get the decoded images from the encoded values
decoded_img1 = decoder(latent_z1)
decoded_img2 = decoder(latent_z2)

#Plot test and decoded images
pred(decoded_img1.numpy())

#Plot more
print('Start interpolation')
for alpha in range(5):
  alpha = 0.2 * alpha
  latent_new = (1 - alpha) * latent_z1 + alpha * latent_z2
  decoded_imgnew = decoder(latent_new)
  pred(decoded_imgnew.numpy())

pred(decoded_img2.numpy())
# Out:
# Start interpolation

# %% [markdown]
# ### 1.6 Sampling with AE

# %%
import tensorflow_probability as tfp

tfd = tfp.distributions
dist = tfd.Normal(loc=0., scale=1)

#Get the encoded values for test images
latent_z = encoder(x_test)

#sample z~p(z)
epsilon = dist.sample([10, 2])

# x~p(x|z)
decoded_from_noise = decoder(epsilon)

#Plot test and decoded images
pred(x_test)
pred(decoded_from_noise.numpy())
# Out:
# WARNING:tensorflow:From c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.

# %%
plot_label_clusters(encoder, x_test, y_test, vae=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:4991, in gather(***failed resolving arguments***)
#    4988 try:
#    4989   # TODO(apassos) find a less bad way of detecting resource variables
#    4990   # without introducing a circular dependency.
# -> 4991   return params.sparse_read(indices, name=name)
#    4992 except AttributeError:
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# AttributeError: 'SymbolicTensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_label_clusters(encoder, x_test, y_test, vae=False)
#
# Cell In[2], line 76, in plot_label_clusters(model, data, labels, vae)
#      74   z_mean, _, _ = model.encoder.predict(data, verbose=0)
#      75 else:
# ---> 76   z_mean = model.predict(data, verbose=0)
#      78 cmap = get_cmap("tab10")  # Colormap for up to 10 discrete classes
#      80 plt.figure(figsize=(12, 10))
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:448, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 @traceback_utils.filter_traceback
#     444 def predict(
#     445     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     446 ):
#     447     # Create an iterator that yields batches of input data.
# --> 448     epoch_iterator = TFEpochIterator(
#     449         x=x,
#     450         batch_size=batch_size,
#     451         steps_per_epoch=steps,
#     452         shuffle=False,
#     453         distribute_strategy=self.distribute_strategy,
#     454         steps_per_execution=self.steps_per_execution,
#     455     )
#     457     # Container that configures and calls callbacks.
#     458     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:666, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     664 super().__init__(*args, **kwargs)
#     665 self._distribute_strategy = distribute_strategy
# --> 666 dataset = self._get_iterator()
#     667 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     668     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     669         dataset
#     670     )
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:675, in TFEpochIterator._get_iterator(self)
#     674 def _get_iterator(self):
# --> 675     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:215, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     211         return x
#     213     return tree.traverse(grab_one, data)
# --> 215 dataset = dataset.map(
#     216     grab_batch, num_parallel_calls=tf.data.AUTOTUNE
#     217 )
#     219 # Default optimizations are disabled to avoid the overhead of
#     220 # (unnecessary) input pipeline graph serialization & deserialization
#     221 options = tf.data.Options()
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# -> 2341 return map_op._map_v2(
#    2342     self,
#    2343     map_func,
#    2344     num_parallel_calls=num_parallel_calls,
#    2345     deterministic=deterministic,
#    2346     synchronous=synchronous,
#    2347     use_unbounded_threadpool=use_unbounded_threadpool,
#    2348     name=name,
#    2349 )
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\map_op.py:57, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#      51 if synchronous:
#      52   raise ValueError(
#      53       "`synchronous` is not supported with `num_parallel_calls`, but"
#      54       " `num_parallel_calls` was set to ",
#      55       num_parallel_calls,
#      56   )
# ---> 57 return _ParallelMapDataset(
#      58     input_dataset,
#      59     map_func,
#      60     num_parallel_calls=num_parallel_calls,
#      61     deterministic=deterministic,
#      62     preserve_cardinality=True,
#      63     use_unbounded_threadpool=use_unbounded_threadpool,
#      64     name=name)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\map_op.py:202, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, use_unbounded_threadpool, name)
#     200 self._input_dataset = input_dataset
#     201 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 202 self._map_func = structured_function.StructuredFunctionWrapper(
#     203     map_func,
#     204     self._transformation_name(),
#     205     dataset=input_dataset,
#     206     use_legacy_function=use_legacy_function)
#     207 if deterministic is None:
#     208   self._deterministic = "default"
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:213, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs.<locals>.grab_batch(i, data)
#     210         return tf.gather(x, i, axis=0)
#     211     return x
# --> 213 return tree.traverse(grab_one, data)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\tree\tree_api.py:88, in traverse(func, structure, top_down)
#      41 @keras_export("keras.tree.traverse")
#      42 def traverse(func, structure, top_down=True):
#      43     """Traverses the given nested structure, applying the given function.
#      44
#      45     The traversal is depth-first. If `top_down` is True (default), parents
#    (...)
#      86         The structured output from the traversal.
#      87     """
# ---> 88     return tree_impl.traverse(func, structure, top_down=top_down)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\tree\optree_impl.py:51, in traverse(func, structure, top_down)
#      45         return optree.tree_unflatten(
#      46             treedef,
#      47             [traverse(func, c, top_down=top_down) for c in children],
#      48         )
#      50 if top_down:
# ---> 51     ret = func(structure)
#      52     if ret is None:
#      53         return traverse_children()
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:210, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs.<locals>.grab_batch.<locals>.grab_one(x)
#     208     return None
#     209 if tf.is_tensor(x):
# --> 210     return tf.gather(x, i, axis=0)
#     211 return x
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:5004, in gather_v2(params, indices, validate_indices, axis, batch_dims, name)
#    4996 @tf_export("gather", v1=[])
#    4997 @dispatch.add_dispatch_support
#    4998 def gather_v2(params,
#    (...)
#    5002               batch_dims=0,
#    5003               name=None):
# -> 5004   return gather(
#    5005       params,
#    5006       indices,
#    5007       validate_indices=validate_indices,
#    5008       name=name,
#    5009       axis=axis,
#    5010       batch_dims=batch_dims)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\deprecation.py:588, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     580         _PRINTED_WARNING[(func, arg_name)] = True
#     581       _log_deprecation(
#     582           'From %s: calling %s (from %s) with %s is deprecated and will '
#     583           'be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     586           'in a future version' if date is None else ('after %s' % date),
#     587           instructions)
# --> 588 return func(*args, **kwargs)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:4993, in gather(***failed resolving arguments***)
#    4991   return params.sparse_read(indices, name=name)
#    4992 except AttributeError:
# -> 4993   return gen_array_ops.gather_v2(params, indices, axis, name=name)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4927, in gather_v2(params, indices, axis, batch_dims, name)
#    4925   batch_dims = 0
#    4926 batch_dims = _execute.make_int(batch_dims, "batch_dims")
# -> 4927 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    4928       "GatherV2", params=params, indices=indices, axis=axis,
#    4929                   batch_dims=batch_dims, name=name)
#    4930 _result = _outputs[:]
#    4931 if _execute.must_record_gradient():
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:732, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     730 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     731 preferred_dtype = preferred_dtype or dtype_hint
# --> 732 return tensor_conversion_registry.convert(
#     733     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     734 )
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:289, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:2701, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2698 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2699 # Session.run call cannot occur between creating and mutating the op.
#    2700 with self._mutation_lock():
# -> 2701   ret = Operation.from_node_def(
#    2702       node_def,
#    2703       self,
#    2704       inputs=inputs,
#    2705       output_types=dtypes,
#    2706       control_inputs=control_inputs,
#    2707       input_types=input_types,
#    2708       original_op=self._default_original_op,
#    2709       op_def=op_def,
#    2710   )
#    2711   self._create_op_helper(ret, compute_device=compute_device)
#    2712 return ret
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1196, in Operation.from_node_def(***failed resolving arguments***)
#    1193     control_input_ops.append(control_op)
#    1195 # Initialize c_op from node_def and other inputs
# -> 1196 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1197 self = Operation(c_op, SymbolicTensor)
#    1198 self._init(g)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Marcus Sjöblom\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1053, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1049   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1050                                          serialized)
#    1052 try:
# -> 1053   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1054 except errors.InvalidArgumentError as e:
#    1055   # Convert to ValueError for backwards compatibility.
#    1056   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %% [markdown]
# # Variational AutoEncoder (VAE)

# %% [markdown]
# ### 2.1 Re-parameterization trick

# %%
# https://keras.io/examples/generative/vae/
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
# VAE encoder
encoder_inputs = keras.Input(shape=(784,),name='EncoderInput')
x = layers.Dense(128, activation='relu',input_shape=(784,),name='Encoder_Layer1')(encoder_inputs)
x = layers.Dense(64, activation='relu',name='Encoder_Layer2')(x)
z_mean = layers.Dense(2, name="z_mean")(x)
z_log_var = layers.Dense(2, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
vae_encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
vae_encoder.summary()

# VAE decoder, indentical to AE decoder
vae_decoder = keras.Sequential(name='Decoder')
vae_decoder.add(layers.Dense(64, activation='relu', input_shape=(2,),name='Decoder_Layer1'))
vae_decoder.add(layers.Dense(128, activation='relu',name='Decoder_Layer2'))
vae_decoder.add(layers.Dense(784, activation='sigmoid',name='Output'))
vae_decoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ EncoderInput (InputLayer) │ (None, 784)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Encoder_Layer1 (Dense)    │ (None, 128)            │        100,480 │ EncoderInput[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Encoder_Layer2 (Dense)    │ (None, 64)             │          8,256 │ Encoder_Layer1[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_mean (Dense)            │ (None, 2)              │            130 │ Encoder_Layer2[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_log_var (Dense)         │ (None, 2)              │            130 │ Encoder_Layer2[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sampling_1 (Sampling)     │ (None, 2)              │              0 │ z_mean[0][0],          │
# │                           │                        │                │ z_log_var[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 108,996 (425.77 KB)
#  Trainable params: 108,996 (425.77 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "Decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Decoder_Layer1 (Dense)               │ (None, 64)                  │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Decoder_Layer2 (Dense)               │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 784)                 │         101,136 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,648 (428.31 KB)
#  Trainable params: 109,648 (428.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.2 Define VAE loss

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss =  ops.mean(
                 ops.sum(
                    ops.square(data-reconstruction),
                 axis=1)
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
vae = VAE(vae_encoder, vae_decoder)
vae.compile(optimizer=keras.optimizers.Adam())
log = vae.fit(x_train, epochs=50, batch_size=256, shuffle=True)
#Plot loss curves
plot_curve(log, valid=False)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.7026 - loss: 87.0324 - reconstruction_loss: 82.3298
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - kl_loss: 2.2326 - loss: 47.2407 - reconstruction_loss: 45.0080
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 2.6996 - loss: 44.8944 - reconstruction_loss: 42.1948
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 3.1375 - loss: 43.1606 - reconstruction_loss: 40.0231
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - kl_loss: 3.3443 - loss: 42.3797 - reconstruction_loss: 39.0354
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 3.5259 - loss: 41.6504 - reconstruction_loss: 38.1245
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 3.6484 - loss: 41.0138 - reconstruction_loss: 37.3654
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - kl_loss: 3.7563 - loss: 40.6550 - reconstruction_loss: 36.8986
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 3.8152 - loss: 40.1790 - reconstruction_loss: 36.3639
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - kl_loss: 3.9171 - loss: 39.8417 - reconstruction_loss: 35.9245
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - kl_loss: 3.9918 - loss: 39.5831 - reconstruction_loss: 35.5914
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - kl_loss: 4.0587 - loss: 39.2029 - reconstruction_loss: 35.1442
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - kl_loss: 4.1386 - loss: 39.0116 - reconstruction_loss: 34.8730
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - kl_loss: 4.2076 - loss: 38.6683 - reconstruction_loss: 34.4606
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - kl_loss: 4.2463 - loss: 38.5208 - reconstruction_loss: 34.2744
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 4.3135 - loss: 38.4575 - reconstruction_loss: 34.1440
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.3410 - loss: 38.2072 - reconstruction_loss: 33.8662
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.3786 - loss: 37.8774 - reconstruction_loss: 33.4988
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - kl_loss: 4.4374 - loss: 37.7407 - reconstruction_loss: 33.3033
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - kl_loss: 4.4587 - loss: 37.6790 - reconstruction_loss: 33.2203
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.4886 - loss: 37.5358 - reconstruction_loss: 33.0471
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.5452 - loss: 37.3623 - reconstruction_loss: 32.8172
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - kl_loss: 4.5666 - loss: 37.1694 - reconstruction_loss: 32.6028
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 4.5900 - loss: 37.1432 - reconstruction_loss: 32.5532
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - kl_loss: 4.6201 - loss: 37.0535 - reconstruction_loss: 32.4334
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - kl_loss: 4.6319 - loss: 36.9340 - reconstruction_loss: 32.3022
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.6533 - loss: 36.8416 - reconstruction_loss: 32.1882
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.6915 - loss: 36.6715 - reconstruction_loss: 31.9800
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - kl_loss: 4.7302 - loss: 36.6309 - reconstruction_loss: 31.9008
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 4.7172 - loss: 36.5581 - reconstruction_loss: 31.8409
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.7352 - loss: 36.4878 - reconstruction_loss: 31.7526
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - kl_loss: 4.7660 - loss: 36.3994 - reconstruction_loss: 31.6334
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - kl_loss: 4.7783 - loss: 36.3491 - reconstruction_loss: 31.5708
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.8052 - loss: 36.2775 - reconstruction_loss: 31.4723
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.7919 - loss: 36.2020 - reconstruction_loss: 31.4101
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.8225 - loss: 36.1686 - reconstruction_loss: 31.3461
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.8148 - loss: 36.0399 - reconstruction_loss: 31.2251
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - kl_loss: 4.8543 - loss: 36.0438 - reconstruction_loss: 31.1895
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 4.8548 - loss: 35.9429 - reconstruction_loss: 31.0881
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.8716 - loss: 35.9833 - reconstruction_loss: 31.1117
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - kl_loss: 4.8939 - loss: 35.9052 - reconstruction_loss: 31.0113
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.8884 - loss: 35.7280 - reconstruction_loss: 30.8396
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.8960 - loss: 35.7102 - reconstruction_loss: 30.8142
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.9160 - loss: 35.7324 - reconstruction_loss: 30.8164
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - kl_loss: 4.9297 - loss: 35.5993 - reconstruction_loss: 30.6697
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.9347 - loss: 35.6363 - reconstruction_loss: 30.7017
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.9577 - loss: 35.6324 - reconstruction_loss: 30.6747
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - kl_loss: 4.9598 - loss: 35.4842 - reconstruction_loss: 30.5244
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - kl_loss: 4.9741 - loss: 35.5391 - reconstruction_loss: 30.5651
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - kl_loss: 4.9862 - loss: 35.4554 - reconstruction_loss: 30.4692

# %%
#Get the encoded values for test images
z_mean, z_log_var, latent_z = vae_encoder(x_test[:10, :])

print(ops.mean(ops.exp(0.5 * z_log_var), axis=-1))
#Get the decoded images from the encoded values
decoded_img = vae_decoder(latent_z)

#Plot test and decoded images
pred(x_test)
pred(decoded_img.numpy())
# Out:
# tf.Tensor(
# [0.1037754  0.15128565 0.13229692 0.08716559 0.08579271 0.11961043
#  0.106535   0.110843   0.09632699 0.05387476], shape=(10,), dtype=float32)

# %%
#Get the encoded values for test images
z_mean1, z_log_var1, latent_z1 = vae_encoder(x_test[:10, :])
z_mean2, z_log_var2, latent_z2= vae_encoder(x_test[10:20, :])

#Get the decoded images from the encoded values
decoded_img1 = vae_decoder(latent_z1)
decoded_img2 = vae_decoder(latent_z2)

#Plot test and decoded images
pred(decoded_img1.numpy())

#Plot more
print('Start interpolation')
for alpha in range(5):
  alpha = 0.2 * alpha
  latent_new = (1 - alpha) * latent_z1 + alpha * latent_z2
  decoded_imgnew = vae_decoder(latent_new)
  pred(decoded_imgnew.numpy())

pred(decoded_img2.numpy())
# Out:
# Start interpolation

# %%
# define standard gaussian
tfd = tfp.distributions
dist_vae = tfd.Normal(loc=0., scale=1)
# sample from gaussian z~p(z)
latent_z = dist_vae.sample([10,2])
# x~p(x|z)
imgs_samples = vae_decoder(latent_z)
pred(imgs_samples.numpy())

# %%
plot_label_clusters(vae, x_test, y_test, vae=True)
# Out:
# <ipython-input-39-a73d9f815748>:78: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap("tab10")  # Colormap for up to 10 discrete classes

# %% [markdown]
# ## 3. Autoencoder using CNN

# %% [markdown]
# ### 3.1 Reshaping data

# %%
x_train = x_train.reshape((len(x_train), 28,28,1))
x_test = x_test.reshape((len(x_test), 28,28,1))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# ### 3.2 Model Definition

# %%
#define encoder network
encoder_cnn = keras.Sequential(name='Encoder_CNN')
encoder_cnn.add(layers.Conv2D(8, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', input_shape=(28,28,1), name='E1'))
encoder_cnn.add(layers.MaxPooling2D((2, 2), padding='same', name='E2'))
encoder_cnn.add(layers.Conv2D(8, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', name='E3'))
encoder_cnn.add(layers.MaxPooling2D((2, 2), padding='same', name='E4'))
encoder_cnn.add(layers.Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', name='E5'))
encoder_cnn.add(layers.MaxPooling2D((2, 2), padding='same', name='E6'))
encoder_cnn.add(layers.Flatten(name='E7'))
encoder_cnn.add(layers.Dense(128, activation='relu',name='E8'))
encoder_cnn.summary()

#define decoder network
decoder_cnn = keras.Sequential(name='Decoder_CNN')
decoder_cnn.add(layers.Dense(256, input_shape=(128,), activation='relu',name='D1'))
decoder_cnn.add(layers.Reshape((4,4,16),name='D2'))
decoder_cnn.add(layers.Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', name='D3'))
decoder_cnn.add(layers.UpSampling2D((2, 2), name='D4'))
decoder_cnn.add(layers.Conv2D(8, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', name='D5'))
decoder_cnn.add(layers.UpSampling2D((2, 2), name='D6'))
decoder_cnn.add(layers.Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', name='D7'))
decoder_cnn.add(layers.UpSampling2D((2, 2), name='D8'))
decoder_cnn.add(layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='Output'))
decoder_cnn.summary()

#define autoencoder by combining encoder and decoder
input_img = keras.Input(shape=(28,28,1), name='Input_Layer')
z = encoder_cnn(input_img)
output_img = decoder_cnn(z)
autoencoder_cnn = keras.models.Model(inputs=input_img, outputs=output_img, name='Autoencoder_CNN')
autoencoder_cnn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "Encoder_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ E1 (Conv2D)                          │ (None, 28, 28, 8)           │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E2 (MaxPooling2D)                    │ (None, 14, 14, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E3 (Conv2D)                          │ (None, 14, 14, 8)           │             584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E4 (MaxPooling2D)                    │ (None, 7, 7, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E5 (Conv2D)                          │ (None, 7, 7, 16)            │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E6 (MaxPooling2D)                    │ (None, 4, 4, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E7 (Flatten)                         │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ E8 (Dense)                           │ (None, 128)                 │          32,896 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34,728 (135.66 KB)
#  Trainable params: 34,728 (135.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "Decoder_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ D1 (Dense)                           │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D2 (Reshape)                         │ (None, 4, 4, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D3 (Conv2D)                          │ (None, 4, 4, 16)            │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D4 (UpSampling2D)                    │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D5 (Conv2D)                          │ (None, 8, 8, 8)             │           1,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D6 (UpSampling2D)                    │ (None, 16, 16, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D7 (Conv2D)                          │ (None, 14, 14, 8)           │             584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ D8 (UpSampling2D)                    │ (None, 28, 28, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Conv2D)                      │ (None, 28, 28, 1)           │              73 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 37,161 (145.16 KB)
#  Trainable params: 37,161 (145.16 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "Autoencoder_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Encoder_CNN (Sequential)             │ (None, 128)                 │          34,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Decoder_CNN (Sequential)             │ (None, 28, 28, 1)           │          37,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 71,889 (280.82 KB)
#  Trainable params: 71,889 (280.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.3 Model Training

# %%
#Configure the model for training
autoencoder_cnn.compile(optimizer='adam', loss='binary_crossentropy')

#Model Training
log = autoencoder_cnn.fit(x_train, x_train, epochs=50, batch_size=128, shuffle=True, validation_split=0.2)

#Plot loss curves
plot_curve(log)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 50s 126ms/step - loss: 0.2821 - val_loss: 0.1429
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 47s 125ms/step - loss: 0.1354 - val_loss: 0.1229
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 122ms/step - loss: 0.1201 - val_loss: 0.1152
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.1126 - val_loss: 0.1103
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 127ms/step - loss: 0.1080 - val_loss: 0.1066
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 124ms/step - loss: 0.1045 - val_loss: 0.1033
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.1017 - val_loss: 0.1010
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 124ms/step - loss: 0.0999 - val_loss: 0.0998
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 124ms/step - loss: 0.0979 - val_loss: 0.0977
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0968 - val_loss: 0.0966
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.0956 - val_loss: 0.0955
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 84s 127ms/step - loss: 0.0943 - val_loss: 0.0945
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 125ms/step - loss: 0.0937 - val_loss: 0.0949
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 122ms/step - loss: 0.0925 - val_loss: 0.0930
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 121ms/step - loss: 0.0920 - val_loss: 0.0924
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 84s 126ms/step - loss: 0.0913 - val_loss: 0.0915
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 124ms/step - loss: 0.0906 - val_loss: 0.0908
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 123ms/step - loss: 0.0902 - val_loss: 0.0901
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 47s 124ms/step - loss: 0.0896 - val_loss: 0.0910
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 125ms/step - loss: 0.0893 - val_loss: 0.0892
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 123ms/step - loss: 0.0886 - val_loss: 0.0895
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 122ms/step - loss: 0.0883 - val_loss: 0.0884
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 121ms/step - loss: 0.0879 - val_loss: 0.0881
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 84s 125ms/step - loss: 0.0872 - val_loss: 0.0884
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 122ms/step - loss: 0.0872 - val_loss: 0.0878
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 121ms/step - loss: 0.0868 - val_loss: 0.0881
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 121ms/step - loss: 0.0864 - val_loss: 0.0869
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 47s 125ms/step - loss: 0.0862 - val_loss: 0.0866
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 80s 121ms/step - loss: 0.0861 - val_loss: 0.0869
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 121ms/step - loss: 0.0857 - val_loss: 0.0865
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.0855 - val_loss: 0.0870
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 124ms/step - loss: 0.0855 - val_loss: 0.0870
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0852 - val_loss: 0.0858
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 121ms/step - loss: 0.0848 - val_loss: 0.0857
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 124ms/step - loss: 0.0846 - val_loss: 0.0853
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 124ms/step - loss: 0.0845 - val_loss: 0.0854
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0844 - val_loss: 0.0849
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.0844 - val_loss: 0.0855
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 125ms/step - loss: 0.0839 - val_loss: 0.0845
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 80s 120ms/step - loss: 0.0839 - val_loss: 0.0847
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 119ms/step - loss: 0.0838 - val_loss: 0.0842
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 123ms/step - loss: 0.0834 - val_loss: 0.0843
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 81s 119ms/step - loss: 0.0833 - val_loss: 0.0837
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 119ms/step - loss: 0.0830 - val_loss: 0.0843
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 119ms/step - loss: 0.0829 - val_loss: 0.0839
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 123ms/step - loss: 0.0830 - val_loss: 0.0835
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 80s 119ms/step - loss: 0.0826 - val_loss: 0.0840
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 119ms/step - loss: 0.0826 - val_loss: 0.0846
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 83s 121ms/step - loss: 0.0824 - val_loss: 0.0838
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 45s 121ms/step - loss: 0.0824 - val_loss: 0.0834

# %% [markdown]
# ### 2.4 Display Results

# %%
#Get the encoded values for test images
encoded_img = encoder_cnn(x_test)

#Get the decoded images from the encoded values
decoded_img = decoder_cnn(encoded_img)

#Plot test and decoded images
pred(decoded_img.numpy())

# %% [markdown]
# ## 3. Autoencoder using Transposed Convolution

# %% [markdown]
# ### 3.1 Model Definition

# %%
#define encoder network
encodertc = keras.Sequential(name='Encoder_CNN')
encodertc.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', input_shape=(28,28,1), name='E1'))
encodertc.add(layers.MaxPooling2D((2, 2), padding='same', name='E2'))
encodertc.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', name='E3'))
encodertc.add(layers.MaxPooling2D((2, 2), padding='same', name='E4'))
#flatten
#dense
encodertc.summary()

#define decoder network
decodertc = keras.Sequential(name='Decoder_Transpose_Conv')
#dense
#reshape
decodertc.add(layers.Conv2DTranspose(32, (3, 3), input_shape=(7,7,32),activation='relu', padding='same',
                                    strides=2, kernel_initializer='he_normal', name='D1'))
decodertc.add(layers.Conv2DTranspose(32, (3, 3), activation='relu', padding='same',
                                    strides=2, kernel_initializer='he_normal', name='D2'))
decodertc.add(layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='Output'))
decodertc.summary()

#define autoencoder by combining encoder and decoder
input_img = keras.Input(shape=(28,28,1), name='Input_Layer')
z = encodertc(input_img)
output_img = decodertc(z)
autoencodertc = keras.models.Model(inputs=input_img, outputs=output_img, name='Fully_Convolutional_Autoencoder')
autoencodertc.summary()
# Out:
# Model: "Encoder_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  E1 (Conv2D)                 (None, 28, 28, 32)        320
#
#  E2 (MaxPooling2D)           (None, 14, 14, 32)        0
#
#  E3 (Conv2D)                 (None, 14, 14, 32)        9248
#
#  E4 (MaxPooling2D)           (None, 7, 7, 32)          0
#
# =================================================================
# Total params: 9568 (37.38 KB)
# Trainable params: 9568 (37.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Decoder_Transpose_Conv"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  D1 (Conv2DTranspose)        (None, 14, 14, 32)        9248
#
#  D2 (Conv2DTranspose)        (None, 28, 28, 32)        9248
#
#  Output (Conv2D)             (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 18785 (73.38 KB)
# Trainable params: 18785 (73.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Fully_Convolutional_Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 28, 28, 1)]       0
#
#  Encoder_CNN (Sequential)    (None, 7, 7, 32)          9568
#
#  Decoder_Transpose_Conv (Se  (None, 28, 28, 1)         18785
#  quential)
#
# =================================================================
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 3.2 Model Training

# %%
#Configure the model for training
autoencoder_tcnn.compile(optimizer='adam', loss='mse')

#Model Training
log = autoencoder_tcnn.fit(x_train, x_train, epochs=5, batch_size=128, shuffle=True, validation_split=0.2)

#Plot loss curves
plot_curve(log)
# Out:
# Epoch 1/5
# 375/375 [==============================] - 6s 13ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 2/5
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 3/5
# 375/375 [==============================] - 4s 11ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 4/5
# 375/375 [==============================] - 4s 12ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 5/5
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0043 - val_loss: 0.0043

# %% [markdown]
# ### 3.3 Display Results

# %%
#Get the encoded values for test images
encoded_img = encoder_tc(x_test)

#Get the decoded images from the encoded values
decoded_img = decoder_tc(encoded_img)

#Plot test and decoded images
pred(decoded_img.numpy())

# %% [markdown]
# ## 4. Image Denoising using Fully Convolutional Autoencoder

# %% [markdown]
# ### 4.1 Preparing Noisy Data

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

pred(x_test_noisy)

# %% [markdown]
# ### 4.2 Model Definition

# %%
#define encoder network
encoder1 = keras.Sequential(name='Encoder_CNN')
encoder1.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28,28,1), name='E1'))
encoder1.add(layers.MaxPooling2D((2, 2), padding='same', name='E2'))
encoder1.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='E3'))
encoder1.add(layers.MaxPooling2D((2, 2), padding='same', name='E4'))
encoder1.summary()

#define decoder network
decoder1 = keras.Sequential(name='Decoder_CNN')
decoder1.add(layers.Conv2DTranspose(32, (3, 3), input_shape=(7,7,32),activation='relu', padding='same',
                                    strides=2, name='D1'))
decoder1.add(layers.Conv2DTranspose(32, (3, 3), activation='relu', padding='same',
                                    strides=2, name='D2'))
decoder1.add(layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='Output'))
decoder1.summary()

#define autoencoder by combining encoder and decoder
input_img = keras.Input(shape=(28,28,1), name='Input_Layer')
z = encoder1(input_img)
output_img = decoder1(z)
autoencoder1 = keras.models.Model(inputs=input_img, outputs=output_img, name='Fully_Convolutional_Autoencoder')
autoencoder1.summary()
# Out:
# Model: "Encoder_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  E1 (Conv2D)                 (None, 28, 28, 32)        320
#
#  E2 (MaxPooling2D)           (None, 14, 14, 32)        0
#
#  E3 (Conv2D)                 (None, 14, 14, 32)        9248
#
#  E4 (MaxPooling2D)           (None, 7, 7, 32)          0
#
# =================================================================
# Total params: 9568 (37.38 KB)
# Trainable params: 9568 (37.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Decoder_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  D1 (Conv2DTranspose)        (None, 14, 14, 32)        9248
#
#  D2 (Conv2DTranspose)        (None, 28, 28, 32)        9248
#
#  Output (Conv2D)             (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 18785 (73.38 KB)
# Trainable params: 18785 (73.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Fully_Convolutional_Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 28, 28, 1)]       0
#
#  Encoder_CNN (Sequential)    (None, 7, 7, 32)          9568
#
#  Decoder_CNN (Sequential)    (None, 28, 28, 1)         18785
#
# =================================================================
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 4.3 Model Training

# %%
#Configure the model for training
autoencoder1.compile(optimizer='adam', loss='binary_crossentropy')

#Model Training
log = autoencoder1.fit(x_train_noisy, x_train, epochs=20, batch_size=128, shuffle=True, validation_split=0.1)

#Plot loss curves
plot_curve(log)
# Out:
# Epoch 1/100
# 422/422 [==============================] - 9s 19ms/step - loss: 0.1980 - val_loss: 0.1241
# Epoch 2/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1167 - val_loss: 0.1131
# Epoch 3/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1104 - val_loss: 0.1095
# Epoch 4/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1072 - val_loss: 0.1067
# Epoch 5/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1053 - val_loss: 0.1054
# Epoch 6/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1040 - val_loss: 0.1041
# Epoch 7/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1030 - val_loss: 0.1034
# Epoch 8/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1023 - val_loss: 0.1026
# Epoch 9/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1016 - val_loss: 0.1020
# Epoch 10/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1011 - val_loss: 0.1017
# Epoch 11/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1006 - val_loss: 0.1011
# Epoch 12/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1002 - val_loss: 0.1013
# Epoch 13/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0998 - val_loss: 0.1013
# Epoch 14/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0995 - val_loss: 0.1000
# Epoch 15/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0992 - val_loss: 0.0997
# Epoch 16/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0989 - val_loss: 0.0997
# Epoch 17/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0986 - val_loss: 0.0992
# Epoch 18/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0984 - val_loss: 0.0990
# Epoch 19/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0982 - val_loss: 0.0989
# Epoch 20/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0980 - val_loss: 0.0987
# Epoch 21/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0978 - val_loss: 0.0985
# Epoch 22/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0976 - val_loss: 0.0983
# Epoch 23/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0975 - val_loss: 0.0982
# Epoch 24/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0973 - val_loss: 0.0981
# Epoch 25/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0972 - val_loss: 0.0980
# Epoch 26/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0971 - val_loss: 0.0983
# Epoch 27/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0970 - val_loss: 0.0979
# Epoch 28/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0968 - val_loss: 0.0977
# Epoch 29/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0967 - val_loss: 0.0976
# Epoch 30/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0967 - val_loss: 0.0975
# Epoch 31/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0966 - val_loss: 0.0974
# Epoch 32/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0965 - val_loss: 0.0973
# Epoch 33/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0964 - val_loss: 0.0973
# Epoch 34/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0963 - val_loss: 0.0972
# Epoch 35/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0962 - val_loss: 0.0970
# Epoch 36/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0962 - val_loss: 0.0975
# Epoch 37/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0962 - val_loss: 0.0971
# Epoch 38/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0960 - val_loss: 0.0970
# Epoch 39/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0960 - val_loss: 0.0969
# Epoch 40/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0959 - val_loss: 0.0969
# Epoch 41/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0959 - val_loss: 0.0972
# Epoch 42/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0958 - val_loss: 0.0968
# Epoch 43/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 44/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0957 - val_loss: 0.0967
# Epoch 45/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0957 - val_loss: 0.0966
# Epoch 46/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0956 - val_loss: 0.0967
# Epoch 47/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0956 - val_loss: 0.0969
# Epoch 48/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0956 - val_loss: 0.0966
# Epoch 49/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 50/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0955 - val_loss: 0.0965
# Epoch 51/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0954 - val_loss: 0.0967
# Epoch 52/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0954 - val_loss: 0.0964
# Epoch 53/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0954 - val_loss: 0.0966
# Epoch 54/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0954 - val_loss: 0.0965
# Epoch 55/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0953 - val_loss: 0.0966
# Epoch 56/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0953 - val_loss: 0.0965
# Epoch 57/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0953 - val_loss: 0.0963
# Epoch 58/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0952 - val_loss: 0.0966
# Epoch 59/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0952 - val_loss: 0.0965
# Epoch 60/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0952 - val_loss: 0.0963
# Epoch 61/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0952 - val_loss: 0.0962
# Epoch 62/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0951 - val_loss: 0.0961
# Epoch 63/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0951 - val_loss: 0.0961
# Epoch 64/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0951 - val_loss: 0.0962
# Epoch 65/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0951 - val_loss: 0.0963
# Epoch 66/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0950 - val_loss: 0.0962
# Epoch 67/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0950 - val_loss: 0.0961
# Epoch 68/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0950 - val_loss: 0.0961
# Epoch 69/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0950 - val_loss: 0.0963
# Epoch 70/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0950 - val_loss: 0.0960
# Epoch 71/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0949 - val_loss: 0.0960
# Epoch 72/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0949 - val_loss: 0.0960
# Epoch 73/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0949 - val_loss: 0.0961
# Epoch 74/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0949 - val_loss: 0.0959
# Epoch 75/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0949 - val_loss: 0.0959
# Epoch 76/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0960
# Epoch 77/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0962
# Epoch 78/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0959
# Epoch 79/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0969
# Epoch 80/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0959
# Epoch 81/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0960
# Epoch 82/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0958
# Epoch 83/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0967
# Epoch 84/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0959
# Epoch 85/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0948 - val_loss: 0.0958
# Epoch 86/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0959
# Epoch 87/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0958
# Epoch 88/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0961
# Epoch 89/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0958
# Epoch 90/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0958
# Epoch 91/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0959
# Epoch 92/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0947 - val_loss: 0.0958
# Epoch 93/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0959
# Epoch 94/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0959
# Epoch 95/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0960
# Epoch 96/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0958
# Epoch 97/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0960
# Epoch 98/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0959
# Epoch 99/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0946 - val_loss: 0.0957
# Epoch 100/100
# 422/422 [==============================] - 8s 19ms/step - loss: 0.0945 - val_loss: 0.0957

# %% [markdown]
# ### 4.4 Display Results

# %%
#Get the encoded values for test images
encoded_img = encoder1(x_test_noisy)

#Get the decoded images from the encoded values
decoded_img = decoder1(encoded_img)

#Plot test and decoded images
denoise_pred(decoded_img.numpy())

# %% [markdown]
# ## 5. Image Colorization using Autoencoder

# %% [markdown]
# ### 5.1 Converting CIFAR10 Data to Grayscale

# %%
import numpy as np
from keras.datasets import cifar10
(x_train, _), (x_test, _) = cifar10.load_data()

def rgb_2_gray(image):
    return np.dot(image[..., :3], [0.299, 0.587, 0.114])

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.


x_train_gray = rgb_2_gray(x_train)
x_test_gray = rgb_2_gray(x_test)
x_train_gray = x_train_gray.astype('float32') / 255.
x_test_gray = x_test_gray.astype('float32') / 255.
x_train_gray = x_train_gray.reshape((len(x_train), 32,32,1))
x_test_gray = x_test_gray.reshape((len(x_test), 32,32,1))

cifar(x_train_gray, x_train)

# %% [markdown]
# ### 5.2 Model Definition

# %%
#define encoder network
encoder2 = keras.Sequential(name='Encoder_CNN')
encoder2.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32,32,1), name='E1'))
encoder2.add(layers.MaxPooling2D((2, 2), padding='same', name='E2'))
encoder2.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='E3'))
encoder2.add(layers.MaxPooling2D((2, 2), padding='same', name='E4'))
encoder2.summary()

#define decoder network
decoder2 = keras.Sequential(name='Decoder_CNN')
decoder2.add(layers.Conv2DTranspose(32, (3, 3), input_shape=(8,8,32),activation='relu', padding='same',
                                    strides=2, name='D1'))
decoder2.add(layers.Conv2DTranspose(32, (3, 3), activation='relu', padding='same',
                                    strides=2, name='D2'))
decoder2.add(layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same', name='Output'))
decoder2.summary()

#define autoencoder by combining encoder and decoder
input_img = keras.Input(shape=(32,32,1), name='Input_Layer')
z = encoder2(input_img)
output_img = decoder2(z)
autoencoder2 = keras.models.Model(inputs=input_img, outputs=output_img, name='Fully_Convolutional_Autoencoder')
autoencoder2.summary()
# Out:
# Model: "Encoder_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  E1 (Conv2D)                 (None, 32, 32, 32)        320
#
#  E2 (MaxPooling2D)           (None, 16, 16, 32)        0
#
#  E3 (Conv2D)                 (None, 16, 16, 32)        9248
#
#  E4 (MaxPooling2D)           (None, 8, 8, 32)          0
#
# =================================================================
# Total params: 9568 (37.38 KB)
# Trainable params: 9568 (37.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Decoder_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  D1 (Conv2DTranspose)        (None, 16, 16, 32)        9248
#
#  D2 (Conv2DTranspose)        (None, 32, 32, 32)        9248
#
#  Output (Conv2D)             (None, 32, 32, 3)         867
#
# =================================================================
# Total params: 19363 (75.64 KB)
# Trainable params: 19363 (75.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "Fully_Convolutional_Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 32, 32, 1)]       0
#
#  Encoder_CNN (Sequential)    (None, 8, 8, 32)          9568
#
#  Decoder_CNN (Sequential)    (None, 32, 32, 3)         19363
#
# =================================================================
# Total params: 28931 (113.01 KB)
# Trainable params: 28931 (113.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 5.3 Model Training

# %%
#Configure the model for training
autoencoder2.compile(optimizer='adam', loss='binary_crossentropy')

#Model Training
log = autoencoder2.fit(x_train_gray, x_train, epochs=100, batch_size=128, shuffle=True, validation_split=0.1)

#Plot loss curves
plot_curve(log)
# Out:
# Epoch 1/100
# 352/352 [==============================] - 10s 26ms/step - loss: 0.6270 - val_loss: 0.5944
# Epoch 2/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5886 - val_loss: 0.5868
# Epoch 3/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5835 - val_loss: 0.5850
# Epoch 4/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5812 - val_loss: 0.5824
# Epoch 5/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5800 - val_loss: 0.5810
# Epoch 6/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5791 - val_loss: 0.5802
# Epoch 7/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5783 - val_loss: 0.5802
# Epoch 8/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5777 - val_loss: 0.5789
# Epoch 9/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5771 - val_loss: 0.5790
# Epoch 10/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5766 - val_loss: 0.5791
# Epoch 11/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5761 - val_loss: 0.5776
# Epoch 12/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5757 - val_loss: 0.5771
# Epoch 13/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5753 - val_loss: 0.5769
# Epoch 14/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5749 - val_loss: 0.5766
# Epoch 15/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5746 - val_loss: 0.5760
# Epoch 16/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5742 - val_loss: 0.5757
# Epoch 17/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5739 - val_loss: 0.5755
# Epoch 18/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5735 - val_loss: 0.5754
# Epoch 19/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5733 - val_loss: 0.5752
# Epoch 20/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5730 - val_loss: 0.5747
# Epoch 21/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5728 - val_loss: 0.5745
# Epoch 22/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5727 - val_loss: 0.5743
# Epoch 23/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5725 - val_loss: 0.5742
# Epoch 24/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5723 - val_loss: 0.5739
# Epoch 25/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5721 - val_loss: 0.5737
# Epoch 26/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5720 - val_loss: 0.5739
# Epoch 27/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5718 - val_loss: 0.5736
# Epoch 28/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5717 - val_loss: 0.5739
# Epoch 29/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5716 - val_loss: 0.5734
# Epoch 30/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5715 - val_loss: 0.5732
# Epoch 31/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5714 - val_loss: 0.5738
# Epoch 32/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5713 - val_loss: 0.5729
# Epoch 33/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5711 - val_loss: 0.5733
# Epoch 34/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5710 - val_loss: 0.5735
# Epoch 35/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5710 - val_loss: 0.5726
# Epoch 36/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5709 - val_loss: 0.5726
# Epoch 37/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5708 - val_loss: 0.5728
# Epoch 38/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5707 - val_loss: 0.5724
# Epoch 39/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5705 - val_loss: 0.5725
# Epoch 40/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5705 - val_loss: 0.5732
# Epoch 41/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5705 - val_loss: 0.5723
# Epoch 42/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5703 - val_loss: 0.5721
# Epoch 43/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5703 - val_loss: 0.5721
# Epoch 44/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5701 - val_loss: 0.5720
# Epoch 45/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5701 - val_loss: 0.5719
# Epoch 46/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5700 - val_loss: 0.5721
# Epoch 47/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5700 - val_loss: 0.5722
# Epoch 48/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5699 - val_loss: 0.5717
# Epoch 49/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5699 - val_loss: 0.5718
# Epoch 50/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5697 - val_loss: 0.5716
# Epoch 51/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5697 - val_loss: 0.5716
# Epoch 52/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5697 - val_loss: 0.5714
# Epoch 53/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5696 - val_loss: 0.5717
# Epoch 54/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5695 - val_loss: 0.5715
# Epoch 55/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5695 - val_loss: 0.5713
# Epoch 56/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5694 - val_loss: 0.5714
# Epoch 57/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5694 - val_loss: 0.5712
# Epoch 58/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5694 - val_loss: 0.5712
# Epoch 59/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5694 - val_loss: 0.5719
# Epoch 60/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5693 - val_loss: 0.5713
# Epoch 61/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5692 - val_loss: 0.5712
# Epoch 62/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5692 - val_loss: 0.5717
# Epoch 63/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5692 - val_loss: 0.5712
# Epoch 64/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5692 - val_loss: 0.5724
# Epoch 65/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5691 - val_loss: 0.5711
# Epoch 66/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5691 - val_loss: 0.5709
# Epoch 67/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5690 - val_loss: 0.5708
# Epoch 68/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5690 - val_loss: 0.5715
# Epoch 69/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5690 - val_loss: 0.5708
# Epoch 70/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5689 - val_loss: 0.5708
# Epoch 71/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5689 - val_loss: 0.5706
# Epoch 72/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5688 - val_loss: 0.5706
# Epoch 73/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5688 - val_loss: 0.5709
# Epoch 74/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5688 - val_loss: 0.5706
# Epoch 75/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5687 - val_loss: 0.5707
# Epoch 76/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5688 - val_loss: 0.5709
# Epoch 77/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5687 - val_loss: 0.5704
# Epoch 78/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5686 - val_loss: 0.5706
# Epoch 79/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5686 - val_loss: 0.5708
# Epoch 80/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5686 - val_loss: 0.5708
# Epoch 81/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5686 - val_loss: 0.5705
# Epoch 82/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5685 - val_loss: 0.5705
# Epoch 83/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5685 - val_loss: 0.5709
# Epoch 84/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5685 - val_loss: 0.5703
# Epoch 85/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5685 - val_loss: 0.5703
# Epoch 86/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5685 - val_loss: 0.5713
# Epoch 87/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5684 - val_loss: 0.5704
# Epoch 88/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5684 - val_loss: 0.5702
# Epoch 89/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5684 - val_loss: 0.5704
# Epoch 90/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5683 - val_loss: 0.5702
# Epoch 91/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5683 - val_loss: 0.5705
# Epoch 92/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5682 - val_loss: 0.5701
# Epoch 93/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5683 - val_loss: 0.5703
# Epoch 94/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5682 - val_loss: 0.5701
# Epoch 95/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5681 - val_loss: 0.5704
# Epoch 96/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5682 - val_loss: 0.5701
# Epoch 97/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5681 - val_loss: 0.5699
# Epoch 98/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5681 - val_loss: 0.5701
# Epoch 99/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5681 - val_loss: 0.5699
# Epoch 100/100
# 352/352 [==============================] - 9s 26ms/step - loss: 0.5681 - val_loss: 0.5703

# %% [markdown]
# ### 5.4 Display Results

# %%
#Get the encoded values for test images
encoded_img = encoder2(x_test_gray)

#Get the decoded images from the encoded values
decoded_img = decoder2(encoded_img)

#Plot test and decoded images
cifar(x_test_gray,decoded_img)
